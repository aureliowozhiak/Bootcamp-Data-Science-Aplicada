# %% [markdown]
# # 03.1 - Entendendo a série temporal
# ## Análise e Previsão de Séries Temporais
#
# Origem do Dataset: https://www.seade.gov.br/coronavirus/
# Cópia feita pela Alura: https://github.com/alura-cursos/Prophet_covid/blob/main/dados_covid_sp.zip

# %%
url = 'https://github.com/alura-cursos/Prophet_covid/raw/main/dados_covid_sp.zip'

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import numpy as np

# %%
dados = pd.read_csv(url, sep = ';', compression='zip')
dados.head()
# Out:
#          nome_munic  codigo_ibge  dia  mes    datahora  casos  casos_novos  \
# 0        Adamantina      3500105   25    2  2020-02-25      0            0
# 1            Adolfo      3500204   25    2  2020-02-25      0            0
# 2             Aguaí      3500303   25    2  2020-02-25      0            0
# 3    Águas da Prata      3500402   25    2  2020-02-25      0            0
# 4  Águas de Lindóia      3500501   25    2  2020-02-25      0            0
#
#        casos_pc    casos_mm7d  obitos  ...               nome_drs cod_drs  \
# 0  0,000000e+00     0,0000000       0  ...                Marília       5
# 1  0,000000e+00     0,0000000       0  ...  São José do Rio Preto      15
# 2  0,000000e+00     0,0000000       0  ...  São João da Boa Vista      14
# 3  0,000000e+00     0,0000000       0  ...  São João da Boa Vista      14
# 4  0,000000e+00     0,0000000       0  ...               Campinas       3
#
#      pop pop_60   area  map_leg map_leg_s  latitude  longitude  semana_epidem
# 0  33894   7398  41199        0       8.0  -21,6820   -51,0737              9
# 1   3447    761  21106        0       8.0  -21,2325   -49,6451              9
# 2  35608   5245  47455        0       8.0  -22,0572   -46,9735              9
# 3   7797   1729  14267        0       8.0  -21,9319   -46,7176              9
# 4  18374   3275   6013        0       8.0  -22,4733   -46,6314              9
#
# [5 rows x 26 columns]

# %%
dados['datahora'] = pd.to_datetime(dados['datahora'],format='%Y-%m-%d')

# %%
mpl.rcParams['font.size'] = 18
mpl.rcParams['figure.figsize'] = (15,8)

# %%
sns.lineplot(data=dados, x='datahora', y='casos')
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos'>

# %% [markdown]
# ## exponencial $$ e^x $$

# %%
eixo_x = np.linspace(-2, 2, 100)
y_exp = np.exp(eixo_x)

# %%
sns.lineplot(x=eixo_x, y=y_exp)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## logaritmo
#
# $$ log_2 2 = 1 $$
# $$ log_2 2^x = x $$
# $$ log_e e^x = x $$

# %%
sns.lineplot(x=eixo_x, y=y_exp)
mpl.pyplot.yscale('log')

# %%
dados_sp = dados.query('nome_munic == "São Paulo"')

# %%
sns.lineplot(data=dados_sp, x='datahora', y='casos')
mpl.pyplot.yscale('log')

# %%
dados_praia_grande = dados[dados['nome_munic'] == 'Praia Grande']
dados_praia_grande
# Out:
#           nome_munic  codigo_ibge  dia  mes   datahora  casos  casos_novos  \
# 459     Praia Grande      3541000   25    2 2020-02-25      0            0
# 1104    Praia Grande      3541000   26    2 2020-02-26      0            0
# 1749    Praia Grande      3541000   27    2 2020-02-27      0            0
# 2394    Praia Grande      3541000   28    2 2020-02-28      0            0
# 3039    Praia Grande      3541000   29    2 2020-02-29      0            0
# ...              ...          ...  ...  ...        ...    ...          ...
# 282969  Praia Grande      3541000    8    5 2021-05-08  15673           35
# 283614  Praia Grande      3541000    9    5 2021-05-09  15697           24
# 284259  Praia Grande      3541000   10    5 2021-05-10  15719           22
# 284904  Praia Grande      3541000   11    5 2021-05-11  15819          100
# 285549  Praia Grande      3541000   12    5 2021-05-12  15926          107
#
#             casos_pc    casos_mm7d  obitos  ...          nome_drs cod_drs  \
# 459     0,000000e+00     0,0000000       0  ...  Baixada Santista      13
# 1104    0,000000e+00     0,0000000       0  ...  Baixada Santista      13
# 1749    0,000000e+00     0,0000000       0  ...  Baixada Santista      13
# 2394    0,000000e+00     0,0000000       0  ...  Baixada Santista      13
# 3039    0,000000e+00     0,0000000       0  ...  Baixada Santista      13
# ...              ...           ...     ...  ...               ...     ...
# 282969  4,946598e+03    34,7142857     516  ...  Baixada Santista      13
# 283614  4,954173e+03    35,7142857     518  ...  Baixada Santista      13
# 284259  4,961117e+03    36,5714286     519  ...  Baixada Santista      13
# 284904  4,992678e+03    40,5714286     519  ...  Baixada Santista      13
# 285549  5,026448e+03    50,2857143     519  ...  Baixada Santista      13
#
#            pop pop_60   area  map_leg map_leg_s  latitude  longitude  \
# 459     316844  47218  14925        0       8.0  -24,0084   -46,4121
# 1104    316844  47218  14925        0       8.0  -24,0084   -46,4121
# 1749    316844  47218  14925        0       8.0  -24,0084   -46,4121
# 2394    316844  47218  14925        0       8.0  -24,0084   -46,4121
# 3039    316844  47218  14925        0       8.0  -24,0084   -46,4121
# ...        ...    ...    ...      ...       ...       ...        ...
# 282969  316844  47218  14925    >5000       1.0  -24,0084   -46,4121
# 283614  316844  47218  14925    >5000       1.0  -24,0084   -46,4121
# 284259  316844  47218  14925    >5000       1.0  -24,0084   -46,4121
# 284904  316844  47218  14925    >5000       1.0  -24,0084   -46,4121
# 285549  316844  47218  14925    >5000       1.0  -24,0084   -46,4121
#
#         semana_epidem
# 459                 9
# 1104                9
# 1749                9
# 2394                9
# 3039                9
# ...               ...
# 282969             18
# 283614             19
# 284259             19
# 284904             19
# 285549             19
#
# [443 rows x 26 columns]

# %%
sns.lineplot(data=dados_praia_grande, x='datahora', y='casos')
# Out:
# <AxesSubplot:xlabel='datahora', ylabel='casos'>

# %%
sns.lineplot(data=dados_praia_grande, x='datahora', y='casos')
mpl.pyplot.yscale('log')
